# %%
# !pip install newscatcherapi
# !pip install colab-env --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: newscatcherapi in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Requirement already satisfied: dateparser>=0.7.6 in /usr/local/lib/python3.10/dist-packages (from newscatcherapi) (1.1.8)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from newscatcherapi) (2.27.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser>=0.7.6->newscatcherapi) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser>=0.7.6->newscatcherapi) (2022.7.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser>=0.7.6->newscatcherapi) (2022.10.31)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser>=0.7.6->newscatcherapi) (5.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->newscatcherapi) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->newscatcherapi) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->newscatcherapi) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->newscatcherapi) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser>=0.7.6->newscatcherapi) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colab-env in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: python-dotenv<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from colab-env) (0.21.1)

# %%
from newscatcherapi import NewsCatcherApiClient
import colab_env

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
import os
from scipy.ndimage import gaussian_gradient_magnitude

import pandas as pd
import numpy as np
import os
# Out:
# Mounted at /content/gdrive

# %%
colab_env.envvar_handler.add_env("NEWSCATCHER_API_KEY", "ROrduTaQPNFJ2j9_0i-WmUKpHij9fQcrPpURILgdrms", overwrite=True)
colab_env.envvar_handler.envload()
searched_topic = 'Ukraine'
api_key = os.getenv("NEWSCATCHER_API_KEY")

# %%
newscatcherapi = NewsCatcherApiClient(x_api_key=api_key)
results = newscatcherapi.get_search(q=searched_topic, lang='en', countries='US', page_size=100)

# %%
titles = []
for i in results['articles']:
    titles.append(i['title'])

# %%
title_words = ''
stopwords = set(STOPWORDS)

# %%
for val in titles:
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    title_words += " ".join(tokens)+" "

# %% [markdown]
# ### WordCloud

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', stopwords = stopwords, min_font_size = 10, colormap='viridis_r')
wordcloud.generate(title_words)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ### WordCloud на карте

# %%
d = os.path.dirname(__file__) if "__file__" in locals() else os.getcwd()
color = np.array(Image.open(os.path.join(d, "ukraine.png")))
color = color[::2, ::2]

mask = color.copy()
mask[mask.sum(axis=2) == 0] = 255

edges = np.mean([gaussian_gradient_magnitude(color[:, :, i] / 255., 2) for i in range(3)], axis=0)
mask[edges > .08] = 255

word_cloud = WordCloud(max_words=2000, relative_scaling=0, mask=mask, width = 800, height = 800, background_color ='#FFFFFF', stopwords = stopwords)

word_cloud.generate(title_words)

plt.figure(figsize = (10, 10), facecolor = None)
plt.axis("off")
plt.imshow(word_cloud)
